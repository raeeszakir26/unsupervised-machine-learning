# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons
import warnings

warnings.filterwarnings('ignore')

# %%
x, y =make_moons(n_samples=250, noise=0.05)

# %%
df = {'data1': x[:, 0], 'data2': x[:, 1], 'output': y}

# %%
dataset = pd.DataFrame(df)
dataset
# Out:
#         data1     data2  output
# 0    0.082924  1.000002       0
# 1    0.171927  0.317503       1
# 2    0.946364 -0.546000       1
# 3    0.692267 -0.432975       1
# 4    1.989821  0.528657       1
# ..        ...       ...     ...
# 245  0.175019 -0.033072       1
# 246  0.286513 -0.165794       1
# 247 -1.017088  0.197613       0
# 248 -0.409163  0.917322       0
# 249  0.577076 -0.446010       1
#
# [250 rows x 3 columns]

# %%
sns.scatterplot(x='data1', y= 'data2', data=dataset)
plt.show()

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN(eps=0.5, min_samples=5)
dataset['predict']=db.fit_predict(dataset)

# %%
sns.scatterplot(x='data1', y= 'data2', data=dataset, hue='predict')
plt.show()

# %%
sns.scatterplot(x='data1', y= 'data2', data=dataset, hue=y)
plt.show()
